# %% [markdown]
# 第一个python程序

# %%
print('hello,word!')
# Out:
# hello,word!

# %% [markdown]
# 变量和变量符

# %%
a = 13
b += a
c
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# Cell In[1], line 2
#       1 a = 13
# ----> 2 b += a
#
# NameError: name 'b' is not defined
